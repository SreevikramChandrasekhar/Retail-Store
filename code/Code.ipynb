# %%
import pandas as pd

# %%
cust_df = pd.read_csv(r"C:\Users\vikra\ALabs\Python\CaseStudies\Python Foundation Case Study 1 - Retail Case Study\Case Study 1 - Retail Case Study\Customer.csv")
cust_df
# Out:
#       customer_Id         DOB Gender  city_code
# 0          268408  02-01-1970      M        4.0
# 1          269696  07-01-1970      F        8.0
# 2          268159  08-01-1970      F        8.0
# 3          270181  10-01-1970      F        2.0
# 4          268073  11-01-1970      M        1.0
# ...           ...         ...    ...        ...
# 5642       274474  19-12-1992      M        2.0
# 5643       267666  24-12-1992      M        6.0
# 5644       270476  25-12-1992      F        3.0
# 5645       269626  27-12-1992      F        5.0
# 5646       274308  29-12-1992      F        5.0
#
# [5647 rows x 4 columns]

# %%
trans_df = pd.read_csv(r"C:\Users\vikra\ALabs\Python\CaseStudies\Python Foundation Case Study 1 - Retail Case Study\Case Study 1 - Retail Case Study\Transactions.csv")
trans_df
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type
# ...

# %%
prod_df = pd.read_csv(r"C:\Users\vikra\ALabs\Python\CaseStudies\Python Foundation Case Study 1 - Retail Case Study\Case Study 1 - Retail Case Study\prod_cat_info.csv")
prod_df
# Out:
#     prod_cat_code          prod_cat  prod_sub_cat_code          prod_subcat
# 0               1          Clothing                  4                 Mens
# 1               1          Clothing                  1                Women
# 2               1          Clothing                  3                 Kids
# 3               2          Footwear                  1                 Mens
# 4               2          Footwear                  3                Women
# 5               2          Footwear                  4                 Kids
# 6               3       Electronics                  4              Mobiles
# 7               3       Electronics                  5            Computers
# 8               3       Electronics                  8  Personal Appliances
# 9               3       Electronics                  9              Cameras
# 10              3       Electronics                 10      Audio and video
# ...

# %%
#Merging to include all transaction table records
t_c_df = pd.merge(trans_df, cust_df, left_on = 'cust_id', right_on = 'customer_Id', how = 'left')
t_c_df
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
# ...

# %%
#Merging to include all transaction table records
cust_final = pd.merge(t_c_df,prod_df,left_on=['prod_cat_code','prod_subcat_code'],right_on=['prod_cat_code','prod_sub_cat_code'],how = 'left')
cust_final
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
# ...

# %%
#Dropping redundant columns to obtain final merged dataset
cust_final.drop(columns = ['customer_Id','prod_sub_cat_code'], inplace = True)
cust_final
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
# ...

# %%
#Attributes and corresponding data
cust_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23053 entries, 0 to 23052
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    23053 non-null  int64
#  1   cust_id           23053 non-null  int64
#  2   tran_date         23053 non-null  object
#  3   prod_subcat_code  23053 non-null  int64
#  4   prod_cat_code     23053 non-null  int64
#  5   Qty               23053 non-null  int64
#  6   Rate              23053 non-null  int64
#  7   Tax               23053 non-null  float64
#  8   total_amt         23053 non-null  float64
#  9   Store_type        23053 non-null  object
#  10  DOB               23053 non-null  object
#  11  Gender            23044 non-null  object
#  12  city_code         23045 non-null  float64
#  13  prod_cat          23053 non-null  object
#  14  prod_subcat       23053 non-null  object
# dtypes: float64(3), int64(6), object(6)
# memory usage: 2.6+ MB

# %%
#Top 10 records
cust_final.head(10)
# Out:
#    transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351  28-02-2014                 1              1   -5
# 1     29258453508   270384  27-02-2014                 5              3   -5
# 2     51750724947   273420  24-02-2014                 6              5   -2
# 3     93274880719   271509  24-02-2014                11              6   -3
# 4     51750724947   273420  23-02-2014                 6              5   -2
# 5     97439039119   272357  23-02-2014                 8              3   -2
# 6     45649838090   273667  22-02-2014                11              6   -1
# 7     22643667930   271489  22-02-2014                12              6   -1
# 8     79792372943   275108  22-02-2014                 3              1   -3
# 9     50076728598   269014  21-02-2014                 8              3   -4
#
#    Rate      Tax  total_amt Store_type         DOB Gender  city_code  \
# ...

# %%
#Last 10 records
cust_final.tail(10)
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 23043     49882891062   271982  25-01-2011                10              5
# 23044     14787475597   273982  25-01-2011                 4              3
# 23045     50691119572   273031  25-01-2011                 6              5
# 23046     40893803228   272049  25-01-2011                11              6
# 23047     30856003613   266866  25-01-2011                 4              2
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type         DOB Gender  city_code  \
# ...

# %%
#Statistics for the numerical columns
cust_final.describe()
# Out:
#        transaction_id        cust_id  prod_subcat_code  prod_cat_code  \
# count    2.305300e+04   23053.000000      23053.000000   23053.000000
# mean     5.007348e+10  271021.746497          6.149091       3.763632
# std      2.898194e+10    2431.692059          3.726372       1.677016
# min      3.268991e+06  266783.000000          1.000000       1.000000
# 25%      2.493864e+10  268935.000000          3.000000       2.000000
# 50%      5.009313e+10  270980.000000          5.000000       4.000000
# 75%      7.533000e+10  273114.000000         10.000000       5.000000
# max      9.998755e+10  275265.000000         12.000000       6.000000
#
#                 Qty          Rate           Tax     total_amt     city_code
# count  23053.000000  23053.000000  23053.000000  23053.000000  23045.000000
# mean       2.432395    636.369713    248.667192   2107.308002      5.482534
# std        2.268406    622.363498    187.177773   2507.561264      2.863499
# ...

# %%
#Frequency Table for categorical columns
categorical_columns = ['Store_type','Gender','prod_cat','prod_subcat']
freq_table = cust_final[categorical_columns].apply(lambda x : x.value_counts())
freq_table
# Out:
#                      Store_type   Gender  prod_cat  prod_subcat
# Academic                    NaN      NaN       NaN        967.0
# Audio and video             NaN      NaN       NaN        952.0
# Bags                        NaN      NaN    1998.0          NaN
# Bath                        NaN      NaN       NaN       1023.0
# Books                       NaN      NaN    6069.0          NaN
# Cameras                     NaN      NaN       NaN        985.0
# Children                    NaN      NaN       NaN       1035.0
# Clothing                    NaN      NaN    2960.0          NaN
# Comics                      NaN      NaN       NaN       1031.0
# Computers                   NaN      NaN       NaN        958.0
# DIY                         NaN      NaN       NaN        989.0
# Electronics                 NaN      NaN    4898.0          NaN
# F                           NaN  11233.0       NaN          NaN
# Fiction                     NaN      NaN       NaN       1043.0
# ...

# %%
cust_final.head(16)
# Out:
#     transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0      80712190438   270351  28-02-2014                 1              1   -5
# 1      29258453508   270384  27-02-2014                 5              3   -5
# 2      51750724947   273420  24-02-2014                 6              5   -2
# 3      93274880719   271509  24-02-2014                11              6   -3
# 4      51750724947   273420  23-02-2014                 6              5   -2
# 5      97439039119   272357  23-02-2014                 8              3   -2
# 6      45649838090   273667  22-02-2014                11              6   -1
# 7      22643667930   271489  22-02-2014                12              6   -1
# 8      79792372943   275108  22-02-2014                 3              1   -3
# 9      50076728598   269014  21-02-2014                 8              3   -4
# 10     29258453508   270384  20-02-2014                 5              3    5
# ...

# %%
cust_final['tran_date'] = pd.to_datetime(cust_final['tran_date'],format = 'mixed')

# %%
min_date = cust_final['tran_date'].min()
print(min_date)
# Out:
# 2011-01-02 00:00:00

# %%
max_date = cust_final['tran_date'].max()
print(max_date)
# Out:
# 2014-12-02 00:00:00

# %%
#Time range of the data
range = max_date - min_date
range
# Out:
# Timedelta('1430 days 00:00:00')

# %%
cust_final.head()
# Out:
#    transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351 2014-02-28                 1              1   -5
# 1     29258453508   270384 2014-02-27                 5              3   -5
# 2     51750724947   273420 2014-02-24                 6              5   -2
# 3     93274880719   271509 2014-02-24                11              6   -3
# 4     51750724947   273420 2014-02-23                 6              5   -2
#
#    Rate      Tax  total_amt Store_type         DOB Gender  city_code  \
# 0  -772  405.300  -4265.300     e-Shop  26-09-1981      M        5.0
# 1 -1497  785.925  -8270.925     e-Shop  11-05-1973      F        8.0
# 2  -791  166.110  -1748.110   TeleShop  27-07-1992      M        8.0
# 3 -1363  429.345  -4518.345     e-Shop  08-06-1981      M        3.0
# 4  -791  166.110  -1748.110   TeleShop  27-07-1992      M        8.0
#
#            prod_cat prod_subcat
# 0          Clothing       Women
# ...

# %%
neg_count = (cust_final['total_amt'] < 0).sum()
neg_count
# Out:
# 2177

# %%
female_df = cust_final[cust_final['Gender'] == 'F']
female_df
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 1         29258453508   270384 2014-02-27                 5              3
# 5         97439039119   272357 2014-02-23                 8              3
# 8         79792372943   275108 2014-02-22                 3              1
# 9         50076728598   269014 2014-02-21                 8              3
# 10        29258453508   270384 2014-02-20                 5              3
# ...               ...      ...        ...               ...            ...
# 23039     62511551321   270394 2011-01-25                 3              2
# 23040     19833039570   271380 2011-01-25                 3              2
# 23042     49584040240   273010 2011-01-25                 5              3
# 23045     50691119572   273031 2011-01-25                 6              5
# 23046     40893803228   272049 2011-01-25                11              6
#
# ...

# %%
male_df = cust_final[cust_final['Gender'] == 'M']
male_df
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351 2014-02-28                 1              1
# 2         51750724947   273420 2014-02-24                 6              5
# 3         93274880719   271509 2014-02-24                11              6
# 4         51750724947   273420 2014-02-23                 6              5
# 6         45649838090   273667 2014-02-22                11              6
# ...               ...      ...        ...               ...            ...
# 23048     94340757522   274550 2011-01-25                12              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23050     85115299378   271020 2011-01-25                 2              6
# 23051     72870271171   270911 2011-01-25                11              5
# 23052     77960931771   271961 2011-01-25                11              5
#
# ...

# %%
#Popular product categories for female dataset
female_df['prod_cat'].value_counts()
# Out:
# prod_cat
# Books               2949
# Electronics         2328
# Home and kitchen    1994
# Footwear            1529
# Clothing            1439
# Bags                 994
# Name: count, dtype: int64

# %%
#Popular product categories for male dataset
male_df['prod_cat'].value_counts()
# Out:
# prod_cat
# Books               3116
# Electronics         2570
# Home and kitchen    2134
# Clothing            1518
# Footwear            1469
# Bags                1004
# Name: count, dtype: int64

# %%
cust_final
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351 2014-02-28                 1              1
# 1         29258453508   270384 2014-02-27                 5              3
# 2         51750724947   273420 2014-02-24                 6              5
# 3         93274880719   271509 2014-02-24                11              6
# 4         51750724947   273420 2014-02-23                 6              5
# ...               ...      ...        ...               ...            ...
# 23048     94340757522   274550 2011-01-25                12              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23050     85115299378   271020 2011-01-25                 2              6
# 23051     72870271171   270911 2011-01-25                11              5
# 23052     77960931771   271961 2011-01-25                11              5
#
# ...

# %%
#City codes with their transaction count
city_counts = cust_final.groupby('city_code').size().reset_index()
city_counts.rename(columns = {0 : 'count'}, inplace = True)
city_counts.sort_values(by = 'count', ascending = False, inplace = True)
city_counts.reset_index(drop = True, inplace = True)
city_counts
# Out:
#    city_code  count
# 0        4.0   2422
# 1        3.0   2411
# 2        5.0   2360
# 3        7.0   2356
# 4       10.0   2333
# 5        8.0   2330
# 6        2.0   2270
# 7        1.0   2258
# 8        9.0   2178
# 9        6.0   2127

# %%
#Percentage of the top city
top_city_percent = ( city_counts.iloc[0]['count'] / city_counts['count'].sum()) * 100
top_city_percent = round(top_city_percent,2)
print(f"{top_city_percent}%")
# Out:
# 10.51%

# %%
cust_final
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351 2014-02-28                 1              1
# 1         29258453508   270384 2014-02-27                 5              3
# 2         51750724947   273420 2014-02-24                 6              5
# 3         93274880719   271509 2014-02-24                11              6
# 4         51750724947   273420 2014-02-23                 6              5
# ...               ...      ...        ...               ...            ...
# 23048     94340757522   274550 2011-01-25                12              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23050     85115299378   271020 2011-01-25                 2              6
# 23051     72870271171   270911 2011-01-25                11              5
# 23052     77960931771   271961 2011-01-25                11              5
#
# ...

# %%
pd.set_option('display.float_format', '{:.6f}'.format)

# %%
store_qty = cust_final.groupby('Store_type')['Qty'].sum().reset_index()
store_qty
# Out:
#        Store_type    Qty
# 0  Flagship store  11133
# 1             MBR  11194
# 2        TeleShop  10984
# 3          e-Shop  22763

# %%
store_amount = cust_final.groupby('Store_type')['total_amt'].sum().reset_index()
store_amount
# Out:
#        Store_type       total_amt
# 0  Flagship store  9715688.190000
# 1             MBR  9674486.055000
# 2        TeleShop  9364781.075000
# 3          e-Shop 19824816.050000

# %%
store_sales = pd.merge(store_amount, store_qty,  on = 'Store_type')
store_sales
# Out:
#        Store_type       total_amt    Qty
# 0  Flagship store  9715688.190000  11133
# 1             MBR  9674486.055000  11194
# 2        TeleShop  9364781.075000  10984
# 3          e-Shop 19824816.050000  22763

# %%
# Quantity and amount sales by store sorted in decreasing order
store_sales.sort_values(by = ['total_amt','Qty'], ascending = [False, False], inplace = True)
store_sales
# Out:
#        Store_type       total_amt    Qty
# 3          e-Shop 19824816.050000  22763
# 0  Flagship store  9715688.190000  11133
# 1             MBR  9674486.055000  11194
# 2        TeleShop  9364781.075000  10984

# %%
cust_final.head(30)
# Out:
#     transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0      80712190438   270351 2014-02-28                 1              1   -5
# 1      29258453508   270384 2014-02-27                 5              3   -5
# 2      51750724947   273420 2014-02-24                 6              5   -2
# 3      93274880719   271509 2014-02-24                11              6   -3
# 4      51750724947   273420 2014-02-23                 6              5   -2
# 5      97439039119   272357 2014-02-23                 8              3   -2
# 6      45649838090   273667 2014-02-22                11              6   -1
# 7      22643667930   271489 2014-02-22                12              6   -1
# 8      79792372943   275108 2014-02-22                 3              1   -3
# 9      50076728598   269014 2014-02-21                 8              3   -4
# 10     29258453508   270384 2014-02-20                 5              3    5
# ...

# %%
store_filtered_df = cust_final[cust_final['Store_type'] == 'Flagship store']
store_filtered_df
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 17        25963520987   274829 2014-02-20                 4              4
# 29        99581788104   267466 2014-02-20                 3              2
# 39        63407734630   271322 2014-02-19                 3              2
# 41        82750983847   267544 2014-02-19                 3              5
# 42        67328698675   268755 2014-02-19                 3              2
# ...               ...      ...        ...               ...            ...
# 23023     87697726895   267014 2011-01-26                 4              4
# 23027     71176929896   269201 2011-01-26                 8              3
# 23030     78766424618   267618 2011-01-26                11              6
# 23033     32887353269   268885 2011-01-25                 3              1
# 23039     62511551321   270394 2011-01-25                 3              2
#
# ...

# %%
store_filtered_df = store_filtered_df[(store_filtered_df['prod_cat'] == 'Clothing') | (store_filtered_df['prod_cat'] == 'Electronics')]
store_filtered_df
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 59        83313344780   271288 2014-02-18                 4              3
# 90        76990911956   270148 2014-02-16                 4              3
# 103       10942311291   271297 2014-02-15                 3              1
# 104       63352996926   272145 2014-02-15                 5              3
# 112       57112244235   268076 2014-02-14                10              3
# ...               ...      ...        ...               ...            ...
# 22984     49993147068   268722 2011-01-28                 8              3
# 22991     69708776426   271039 2011-01-28                 5              3
# 23007     71176929896   269201 2011-01-27                 8              3
# 23027     71176929896   269201 2011-01-26                 8              3
# 23033     32887353269   268885 2011-01-25                 3              1
#
# ...

# %%
#Total Amount earned in the Electronics and Clothing category via Flagship stores
total_amount = store_filtered_df['total_amt'].sum()
total_amount = round(total_amount,2)
total_amount
# Out:
# 3409559.27

# %%
#Total amount earned from male customers via Electronics Category
male_ele_df = cust_final[(cust_final['Gender'] == 'M') & (cust_final['prod_cat'] == 'Electronics')]
total_sum = male_ele_df['total_amt'].sum()
total_sum = round(total_sum,2)
total_sum
# Out:
# 5703109.42

# %%
cust_final.head()
# Out:
#    transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351 2014-02-28                 1              1   -5
# 1     29258453508   270384 2014-02-27                 5              3   -5
# 2     51750724947   273420 2014-02-24                 6              5   -2
# 3     93274880719   271509 2014-02-24                11              6   -3
# 4     51750724947   273420 2014-02-23                 6              5   -2
#
#    Rate        Tax    total_amt Store_type         DOB Gender  city_code  \
# 0  -772 405.300000 -4265.300000     e-Shop  26-09-1981      M   5.000000
# 1 -1497 785.925000 -8270.925000     e-Shop  11-05-1973      F   8.000000
# 2  -791 166.110000 -1748.110000   TeleShop  27-07-1992      M   8.000000
# 3 -1363 429.345000 -4518.345000     e-Shop  08-06-1981      M   3.000000
# 4  -791 166.110000 -1748.110000   TeleShop  27-07-1992      M   8.000000
#
#            prod_cat prod_subcat
# 0          Clothing       Women
# ...

# %%
amt_filtered_df = cust_final[cust_final['total_amt'] > 0]
amt_filtered_df.reset_index(drop = True, inplace = True)
amt_filtered_df
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0         29258453508   270384 2014-02-20                 5              3
# 1         25455265351   267750 2014-02-20                12              6
# 2          1571002198   275023 2014-02-20                 6              5
# 3         36554696014   269345 2014-02-20                 3              5
# 4         56814940239   268799 2014-02-20                 7              5
# ...               ...      ...        ...               ...            ...
# 20871     94340757522   274550 2011-01-25                12              5
# 20872     89780862956   270022 2011-01-25                 4              1
# 20873     85115299378   271020 2011-01-25                 2              6
# 20874     72870271171   270911 2011-01-25                11              5
# 20875     77960931771   271961 2011-01-25                11              5
#
# ...

# %%
cust_trans = amt_filtered_df.groupby('cust_id')['transaction_id'].nunique()
cust_trans
# Out:
# cust_id
# 266783     4
# 266784     3
# 266785     7
# 266788     4
# 266794    11
#           ..
# 275257     4
# 275261     3
# 275262     2
# 275264     2
# 275265     3
# Name: transaction_id, Length: 5506, dtype: int64

# %%
#Customers with transactions greater than 10
cust_trans = cust_trans[cust_trans > 10]
cust_trans
# Out:
# cust_id
# 266794    11
# 270535    11
# 270803    11
# 272741    11
# 273014    11
# 274227    11
# Name: transaction_id, dtype: int64

# %%
cust_final
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351 2014-02-28                 1              1
# 1         29258453508   270384 2014-02-27                 5              3
# 2         51750724947   273420 2014-02-24                 6              5
# 3         93274880719   271509 2014-02-24                11              6
# 4         51750724947   273420 2014-02-23                 6              5
# ...               ...      ...        ...               ...            ...
# 23048     94340757522   274550 2011-01-25                12              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23050     85115299378   271020 2011-01-25                 2              6
# 23051     72870271171   270911 2011-01-25                11              5
# 23052     77960931771   271961 2011-01-25                11              5
#
# ...

# %%
cust_final['DOB'] = pd.to_datetime(cust_final['DOB'], format = '%d-%m-%Y')

# %%
max_date = cust_final['tran_date'].max()
max_date
# Out:
# Timestamp('2014-12-02 00:00:00')

# %%
#Dataframe filtered by customers aged between 25 and 35 years
age_filtered_df = cust_final[((max_date - cust_final['DOB']).dt.days/365 >= 25 ) & ((max_date - cust_final['DOB']).dt.days/365 <= 35)]
age_filtered_df
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351 2014-02-28                 1              1
# 3         93274880719   271509 2014-02-24                11              6
# 5         97439039119   272357 2014-02-23                 8              3
# 6         45649838090   273667 2014-02-22                11              6
# 11        25455265351   267750 2014-02-20                12              6
# ...               ...      ...        ...               ...            ...
# 23041     39737254095   272286 2011-01-25                 2              6
# 23042     49584040240   273010 2011-01-25                 5              3
# 23045     50691119572   273031 2011-01-25                 6              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23052     77960931771   271961 2011-01-25                11              5
#
# ...

# %%
prod_filtered_df = age_filtered_df[(age_filtered_df['prod_cat'] == 'Electronics') | (age_filtered_df['prod_cat'] == 'Books')] 
prod_filtered_df
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 5         97439039119   272357 2014-02-23                 8              3
# 21         9647515879   268934 2014-02-20                 7              5
# 24        68325723297   268516 2014-02-20                 9              3
# 25        73235813024   268774 2014-02-20                 3              5
# 41        82750983847   267544 2014-02-19                 3              5
# ...               ...      ...        ...               ...            ...
# 23034     28972634039   275227 2011-01-25                 9              3
# 23037      9423947512   267383 2011-01-25                 3              5
# 23042     49584040240   273010 2011-01-25                 5              3
# 23045     50691119572   273031 2011-01-25                 6              5
# 23052     77960931771   271961 2011-01-25                11              5
#
# ...

# %%
#Total amount earned via Electronics and Books category
total_amt = prod_filtered_df['total_amt'].sum()
total_amt = round(total_amt,2)
total_amt
# Out:
# 10312581.57

# %%
age_filtered_df
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351 2014-02-28                 1              1
# 3         93274880719   271509 2014-02-24                11              6
# 5         97439039119   272357 2014-02-23                 8              3
# 6         45649838090   273667 2014-02-22                11              6
# 11        25455265351   267750 2014-02-20                12              6
# ...               ...      ...        ...               ...            ...
# 23041     39737254095   272286 2011-01-25                 2              6
# 23042     49584040240   273010 2011-01-25                 5              3
# 23045     50691119572   273031 2011-01-25                 6              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23052     77960931771   271961 2011-01-25                11              5
#
# ...

# %%
time_filtered_df = age_filtered_df[(age_filtered_df['tran_date'] >= '2014-01-01') & (age_filtered_df['tran_date'] <= '2014-03-01')]
time_filtered_df
# Out:
#       transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0        80712190438   270351 2014-02-28                 1              1
# 3        93274880719   271509 2014-02-24                11              6
# 5        97439039119   272357 2014-02-23                 8              3
# 6        45649838090   273667 2014-02-22                11              6
# 11       25455265351   267750 2014-02-20                12              6
# ...              ...      ...        ...               ...            ...
# 1049     22308679379   267929 2014-01-01                10              5
# 1055      9835488096   273310 2014-01-01                11              5
# 1060     69378805450   273472 2014-01-01                 1              2
# 1062     71241456072   268863 2014-01-01                 3              5
# 1063     69368153122   273627 2014-01-01                 7              5
#
#       Qty  Rate        Tax    total_amt      Store_type        DOB Gender  \
# ...

# %%
#Total amount spent between 1st Jan 2014 and 1st Mar 2014
total_amount = time_filtered_df['total_amt'].sum()
total_amount
# Out:
# 611712.53

# %%
cust_final
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351 2014-02-28                 1              1
# 1         29258453508   270384 2014-02-27                 5              3
# 2         51750724947   273420 2014-02-24                 6              5
# 3         93274880719   271509 2014-02-24                11              6
# 4         51750724947   273420 2014-02-23                 6              5
# ...               ...      ...        ...               ...            ...
# 23048     94340757522   274550 2011-01-25                12              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23050     85115299378   271020 2011-01-25                 2              6
# 23051     72870271171   270911 2011-01-25                11              5
# 23052     77960931771   271961 2011-01-25                11              5
#
# ...

# %%
continuous_vars = cust_final.select_dtypes(include = ['float64','int64']).columns
discrete_vars = cust_final.select_dtypes(include = ['object','category']).columns

# %%
#Histogram of all the continuos variables 

import matplotlib.pyplot as plt

cust_final[continuous_vars].hist(bins=10, figsize=(10, 10))
plt.suptitle('Histograms for Continuous Variables')
plt.show()

# %%
#Frequency table for all the discrete variables
for var in discrete_vars:
    print(f"Frequency table for {var}:")
    print(cust_final[var].value_counts())
    print("\n")
# Out:
# Frequency table for Store_type:
# Store_type
# e-Shop            9311
# MBR               4661
# Flagship store    4577
# TeleShop          4504
# Name: count, dtype: int64
#
#
# Frequency table for Gender:
# Gender
# M    11811
# F    11233
# Name: count, dtype: int64
#
#
# Frequency table for prod_cat:
# prod_cat
# Books               6069
# Electronics         4898
# Home and kitchen    4129
# Footwear            2999
# Clothing            2960
# Bags                1998
# Name: count, dtype: int64
#
#
# Frequency table for prod_subcat:
# prod_subcat
# Women                  3048
# Mens                   2912
# Kids                   1997
# Tools                  1062
# Fiction                1043
# Kitchen                1037
# Children               1035
# Mobiles                1031
# Comics                 1031
# Bath                   1023
# Furnishing             1007
# Non-Fiction            1004
# DIY                     989
# Cameras                 985
# ...
